# %%
import numpy as np
import pandas as pd
from sklearn import svm
from matplotlib import pyplot , style
style.use('ggplot')

# %%
df = pd.read_csv('res1.csv')

# %%
df.head()
# Out:
#                   Date          UNIX Ticker  Profit Margin (ttm)  \
# 0  2004-01-30 19:01:02  1.075511e+09      a              -0.2956
# 1  2004-04-13 04:07:11  1.081847e+09      a              -0.2556
# 2  2004-12-13 21:37:34  1.102995e+09      a               0.0486
# 3  2005-01-22 05:17:19  1.106393e+09      a               0.0486
# 4  2006-01-09 02:35:16  1.136796e+09      a               0.0638
#
#    Total Debt/Equity (mrq)  Price/Book (mrq)  Return on Assets (ttm)  \
# 0                    0.407              6.01                 -0.2495
# 1                    0.375              4.98                 -0.2359
# 2                    0.323              3.24                  0.0526
# 3                    0.322              3.04                  0.0526
# 4                    0.000              4.26                  0.0168
#
#       SNPDate     SNPValue  StockPrice  Absolute_SNP500_Perfomance  \
# 0  2004-01-30  1131.130005   25.147392                    0.000000
# 1  2004-04-13  1129.439941   21.156284                   -0.149414
# 2  2004-12-13  1198.680054   16.264618                    5.971909
# 3  2005-01-19  1184.630005   15.050230                    4.729783
# 4  2006-01-09  1290.150024   23.571416                   14.058509
#
#    YtY_Stock_Price_Value_Change  YtY_SNP500_Value_Change  \
# 0                      0.000000                 0.000000
# 1                    -15.870863                -0.149414
# 2                    -23.121574                 6.130482
# 3                     -7.466443                -1.172127
# 4                     56.618314                 8.907424
#
#    Absolute_Stock_Perfomance  Absolute_Stock_Perfomance_Flag  \
# 0                   0.000000                               0
# 1                 -15.721449                               0
# 2                 -41.294752                               0
# 3                 -44.881710                               0
# 4                 -20.325466                               0
#
#    YtY_Stock_Perfomance  YtY_Stock_Perfomance_Flag
# 0              0.000000                          0
# 1            -15.721449                          0
# 2            -29.252056                          0
# 3             -6.294316                          0
# 4             47.710890                          1

# %%
df.drop(['Date','SNPDate'],1,inplace=True)
